# %% [markdown]
# ![scene00101.png](attachment:5efe532b-eb5c-4c34-a322-ddd37408adb0.png)![scene00251.png](attachment:a0e80c87-4a9a-40d9-8bfa-58b60038b3d8.png)

# %% [markdown]
# # Loss Function and Optimization in Neural Networks
#
# By the end of the last lesson, our data was processed and our model was specified. Currently, all of the 600,000 or so weights have random values and so the model has random predictions. By training the model, we'll modify these weights and improve the predictions. But before training the model, we'll need to specify a loss function.

# %% [markdown]
# ## Loss Function: Categorical Cross-Entropy
#
# Since we're constructing a multiclass classifier, we'll use categorical cross-entropy loss. This loss function checks to see if our model has done a good job with classifying an image by comparing the model's prediction to the true label. The categorical cross-entropy loss looks at these two vectors and returns a lower value if the two vectors agree regarding what's in the image.

# %% [markdown]
# ![scene02301.png](attachment:a2c79146-9bf6-4e70-924e-f288fb70676c.png)

# %% [markdown]
# ![scene03151.png](attachment:c31e47b8-f126-47f1-bd22-aea9c46bba0e.png)
# ![Screenshot 2023-10-08 at 1.25.23 PM.png](attachment:ef01d094-77e4-4634-a7b0-cfd6ddd42fa7.png)

# %% [markdown]
# ![scene03551.png](attachment:e947862b-d4b2-4c1c-b7a8-88aec3e7b186.png)

# %% [markdown]
# ## Optimization: Gradient Descent
#
# The standard method for descending a loss function is called gradient descent. You've been introduced to a number of ways to perform gradient descent and each method in Keras has a corresponding optimizer. In this lesson, the examples will always use RMSProp as an optimizer.

# %% [markdown]
# ![scene04301.png](attachment:9a6eacd2-5adc-4ee0-83ae-bfbab3164b17.png)![scene05201.png](attachment:c12c1e44-6ee0-4e15-bd0c-f0475ea246fa.png)![scene05401.png](attachment:c4840333-ffee-4577-afef-4e04482d38fe.png)

# %% [markdown]
# Once we've compiled the model, we can check to see what kind of accuracy it already has on the test set before we train it.

# %% [markdown]
# ![scene06501.png](attachment:8203b63f-5b55-4564-a133-648b894dc157.png)

# %% [markdown]
# ### Optional Resources
#
# -   If you'd like more details about fully connected layers in Keras,
#     check out the <a href="https://keras.io/layers/core/"
#     target="_blank">documentation</a> for the Dense layer. You can
#     change the way the weights are initialized through supplying values
#     for the `kernel_initializer` and `bias_initializer` parameters. Note
#     that the default values are `'glorot_uniform'`, and `'zeros'`,
#     respectively. You can read more about how each of these initializers
#     work in the corresponding Keras
#     <a href="https://keras.io/initializers/"
#     target="_blank">documentation</a>.
# -   There are many different
#     <a href="https://keras.io/losses/" target="_blank">loss functions</a>
#     in Keras. For this lesson, we will only use
#     `categorical_crossentropy`.
# -   Check out the
#     <a href="https://keras.io/optimizers/" target="_blank">list of available
#     optimizers</a> in Keras. The optimizer is specified when you compile
#     the model (in Step 7 of the notebook).
#     -   `'sgd'` : SGD
#     -   `'rmsprop'` : RMSprop
#     -   `'adagrad'` : Adagrad
#     -   `'adadelta'` : Adadelta
#     -   `'adam'` : Adam
#     -   `'adamax'` : Adamax
#     -   `'nadam'` : Nadam
#     -   `'tfoptimizer'` : TFOptimizer
