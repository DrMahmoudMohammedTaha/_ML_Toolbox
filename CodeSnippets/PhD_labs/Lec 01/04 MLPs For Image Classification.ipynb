# %% [markdown]
# ![scene00151.png](attachment:2c6b09c5-8bae-4d33-8a3d-25d98d054db6.png)

# %% [markdown]
# # Creating a Neural Network for Handwritten Digits Recognition
#
# In this lesson, we'll create a neural network for discovering patterns in our data. After training, we'll be able to use the network to classify the digits contained in new images.

# %% [markdown]
# ## Neural Network Architecture
#
# Since our data points are vectors with 784 entries, the input layer will have 784 nodes. Let's start with two hidden layers, each containing 512 nodes. Our output layer has to distinguish between 10 different digits, so it will have 10 nodes. We'll use a softmax activation function in the output layer to obtain probabilities for each potential digit.

# %% [markdown]
# ![scene01201.png](attachment:bbbf3361-d229-4a0a-9cb3-7de7091cc28a.png)

# %% [markdown]
# ### Model Specification
#
# This model is a good starting point, but we'll make it even better by adding ReLU activation functions to all hidden layers and incorporating dropout layers to minimize overfitting.

# %% [markdown]
# ![scene01701.png](attachment:ceffbb57-524e-445c-a81a-b1d465cf3f3c.png)

# %% [markdown]
# ![scene02301.png](attachment:d201a3d0-c762-4103-a8a7-48420d1b950e.png)

# %% [markdown]
# ### Model Specification
#
# We'll now specify this drafted model in Keras. We'll use a flatten layer to convert the image matrix's input to a vector. Then, we'll add two hidden layers with ReLU activation functions. Dropout layers will be added to minimize overfitting.

# %% [markdown]
# ![scene02901.png](attachment:ddb580e9-c557-413c-a96c-425c4844bb0d.png)
# ![scene04001.png](attachment:25f7d394-f775-45a2-8a76-a00dcd6edadc.png)
# ![scene04651.png](attachment:a2fe0dde-c6ac-4ff5-beeb-2ba12cf82838.png)
# ![scene04901.png](attachment:1ed02635-d805-47a3-9978-f44897ea674d.png)

# %% [markdown]
# ###
#
# ### Optional Resources
#
# -   Check out the
#     <a href="https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf"
#     target="_blank">first research paper</a> to propose dropout as a
#     technique for overfitting.
# -   Here's the Keras <a href="https://keras.io/layers/core/#flatten"
#     target="_blank">documentation</a> for the Flatten layer.
# -   If you'd like more information on activation functions, check out
#     this <a href="http://cs231n.github.io/neural-networks-1/#actfun"
#     target="_blank">website</a>.
